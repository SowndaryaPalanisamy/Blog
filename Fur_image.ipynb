# %% [markdown]
# <a href="https://colab.research.google.com/github/SowndaryaPalanisamy/Blog/blob/master/Fur_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
flags = [i for i in dir(cv2) if i.startswith('COLOR_')]

# %%
len(flags)
# Out:
# 274

# %%
flags[40]
# Out:
# 'COLOR_BGR2HLS'

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
nemo = cv2.imread('y2.jpg')
plt.imshow(nemo)
plt.show()

# %%
nemo = cv2.cvtColor(nemo, cv2.COLOR_BGR2RGB)
plt.imshow(nemo)
plt.show()

# %%
 hsv_nemo = cv2.cvtColor(nemo, cv2.COLOR_RGB2HSV)
 light_orange = (0,0,0)
dark_orange = (170,174,148)
mask = cv2.inRange(hsv_nemo, light_orange, dark_orange)
result = cv2.bitwise_and(nemo, nemo, mask=mask)
#plt.subplot(1, 3, 1)
plt.imshow(nemo)
plt.show()
#plt.subplot(1, 3, 3)
plt.imshow(mask, cmap="gray")
plt.show()
#plt.subplot(1, 3, 2)
plt.imshow(result)
plt.show()
